# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd 
import numpy as np

# %%
from webdriver_manager.chrome import ChromeDriverManager

# %%
driver= webdriver.Chrome(ChromeDriverManager().install())
# Out:
# Trying to download new driver from http://chromedriver.storage.googleapis.com/80.0.3987.106/chromedriver_win32.zip
# Unpack archive C:\Users\RIKKI\.wdm\drivers\chromedriver\80.0.3987.106\win32\chromedriver.zip

# %%
i=1

# %%
Ratings=[]
Total_no_of_ratings=[]
Total_reviews=[]
Price=[]
Product_name=[]
Status=[]

# %%
for i in range(1,10):
    driver.get('https://www.flipkart.com/mobiles/pr?sid=tyy%2C4io&q=iphone&otracker=categorytree&page='+str(i))
    page_soup=driver.page_source
    page_soup=BeautifulSoup(page_soup)
    container=page_soup.findAll(name='a',attrs={'class':'_31qSD5'})
    for i in range(len(container)):
        product=container[i]
        try:
            Status.append(product.find('span',attrs={'class':'_1GJ2ZM'}).text) #status
        except:
            Status.append(np.nan)
        Product_name.append(product.find('div',attrs={'class':'_3wU53n'}).text) #Device name
        Ratings.append(product.find('span',attrs={'class':'_2_KrJI'}).text) #rating
        Total_no_of_ratings.append(product.find('span',attrs={'class':'_38sUEc'}).text.split(' ')[0])  #Total rating
        Total_reviews.append(product.find('span',attrs={'class':'_38sUEc'}).text.split(' ')[1].split()[-1])  #Total reviews
        Price.append(product.find('div', attrs={'class':'_1vC4OE _2rQ-NK'}).text.replace('₹','Rs '))  #Total price

# %%
driver.get('https://www.flipkart.com/mobiles/pr?sid=tyy%2C4io&q=iphone&otracker=categorytree&page='+str(1))

# %%
page_soup=driver.page_source

# %%
page_soup=BeautifulSoup(page_soup)

# %%
page_soup
# Out:
# <html lang="en"><head><script async="async" src="https://dpm.demdex.net/id?d_visid_ver=1.5.4&amp;d_rtbd=json&amp;d_ver=2&amp;d_orgid=17EB401053DAF4840A490D4C%40AdobeOrg&amp;d_nsid=0&amp;d_mid=45007887529084434339028391079392499088&amp;d_cb=s_c_il%5B0%5D._setAudienceManagerFields" type="text/javascript"></script><script async="async" src="https://flipkart.d1.sc.omtrdc.net/id?d_visid_ver=1.5.4&amp;callback=s_c_il%5B0%5D._setAnalyticsFields&amp;mcorgid=17EB401053DAF4840A490D4C%40AdobeOrg&amp;mid=45007887529084434339028391079392499088" type="text/javascript"></script><script async="async" src="https://dpm.demdex.net/id?d_visid_ver=1.5.4&amp;d_rtbd=json&amp;d_ver=2&amp;d_orgid=17EB401053DAF4840A490D4C%40AdobeOrg&amp;d_nsid=0&amp;d_cb=s_c_il%5B0%5D._setMarketingCloudFields" type="text/javascript"></script>
# <link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/>
# <link href="https://img1a.flixcart.com" rel="dns-prefetch"/>
# ...

# %%
container=page_soup.findAll(name='a',attrs={'class':'_31qSD5'})

# %%
container
# Out:
# [<a class="_31qSD5" href="/apple-iphone-7-black-32-gb/p/itmen6daftcqwzeg?pid=MOBEMK62PN2HU7EE&amp;lid=LSTMOBEMK62PN2HU7EEINTGNU&amp;marketplace=FLIPKART&amp;srno=s_1_1&amp;otracker=search&amp;fm=organic&amp;iid=6dd4b145-cdc7-4a3d-80ec-b8ce0fe31c5e.MOBEMK62PN2HU7EE.SEARCH&amp;ssid=ghvwutm60w0000001586243259871&amp;qH=0b3f45b266a97d70" rel="noopener noreferrer" target="_blank"><div class="_3SQWE6"><div class="_1OCn9C"><div style="-webkit-filter:grayscale(1);-moz-filter:grayscale(1);-o-filter:grayscale(1);-ms-filter:grayscale(1);filter:grayscale(1);opacity:0.6"><div class="_3BTv9X" style="height:200px;width:200px"><img alt="Apple iPhone 7 (Black, 32 GB)" class="_1Nyybr _30XEf0" src="https://rukminim1.flixcart.com/image/312/312/k12go7k0/mobile/7/e/e/apple-iphone-7-mn8x2hn-a-original-imafkqcqhzxuvcpd.jpeg?q=70"/></div></div><div class="_3aV9Tq"><span class="_1GJ2ZM">Not Deliverable</span></div></div><div class="_2lesQu"><div class="_1O_CiZ"><span class="_1iHA1p"><div class="_2kFyHg"><labe
# ...

# %%
print(len(container))
# Out:
# 24

# %%
product1.img['alt']
# Out:
# 'Apple iPhone 7 (Black, 32 GB)'

# %%
#print(BeautifulSoup.prettify(container[0]))

# %%
product1=container[0]

# %%
product1.find('span',attrs={'class':'_1GJ2ZM'}).text
# Out:
# 'Not Deliverable'

# %%
product1.find('div',attrs={'class':'_3wU53n'}).text
# Out:
# 'Apple iPhone 7 (Black, 32 GB)'

# %%
product1.find('span',attrs={'class':'_2_KrJI'}).text
# Out:
# '4.5'

# %%
Total_ratings=product1.find('span',attrs={'class':'_38sUEc'}).text.split(' ')[0]
Total_ratings
# Out:
# '86,089'

# %%
product1.find('span',attrs={'class':'_38sUEc'}).text.split(' ')[1]
#Total_revies
# Out:
# 'Ratings\xa0&\xa08,689'

# %%
Total_reviews=product1.find('span',attrs={'class':'_38sUEc'}).text.split(' ')[1].split()[-1]
Total_reviews
# Out:
# '8,689'

# %%
product1.find('div', attrs={'class':'_1vC4OE _2rQ-NK'}).text.replace('₹','Rs ')
# Out:
# 'Rs 29,499'

# %%
Ratings=[]
Total_no_of_ratings=[]
Total_reviews=[]
Price=[]
Product_name=[]
Status=[]

# %%
for i in range(len(container)):
    product=container[i]
    Status.append(product.find('span',attrs={'class':'_1GJ2ZM'}).text) #status
    Product_name.append(product.find('div',attrs={'class':'_3wU53n'}).text) #Device name
    Ratings.append(product.find('span',attrs={'class':'_2_KrJI'}).text) #rating
    Total_no_of_ratings.append(product.find('span',attrs={'class':'_38sUEc'}).text.split(' ')[0])  #Total rating
    Total_reviews.append(product.find('span',attrs={'class':'_38sUEc'}).text.split(' ')[1].split()[-1])  #Total reviews
    Price.append(product.find('div', attrs={'class':'_1vC4OE _2rQ-NK'}).text.replace('₹','Rs '))  #Total price

# %%
Ratings
# Out:
# ['4.5',
#  '4.7',
#  '4.7',
#  '4.5',
#  '4.7',
#  '4.5',
#  '4.5',
#  '4.7',
#  '4.5',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.7',
#  '4.6',
#  '4.6',
#  '4.5',
#  '4.5',
#  '4.7',
#  '4.7',
#  '4.6',
#  '4.5']

# %%
import numpy as np

# %%
Product_Details={'Product_name':Product_name,'Ratings':Ratings,'Total_no_of_ratings':Total_no_of_ratings,'Total_reviews':Total_reviews,'Price':Price,'Status':Status}

# %%
Product_Details=pd.DataFrame(Product_Details)
Product_Details
# Out:
#                                          Product_name Ratings  \
# 0              Apple iPhone 7 (PRODUCT) (Red, 256 GB)     4.7
# 1       Apple iPhone 8 Plus (PRODUCT)RED (Red, 64 GB)     4.6
# 2                 Apple iPhone 11 Pro (Silver, 64 GB)     4.7
# 3                  Apple iPhone X (Space Gray, 64 GB)     4.6
# 4                Apple iPhone XS (Space Grey, 512 GB)     4.7
# 5             Apple iPhone 7 Plus (Rose Gold, 128 GB)     4.5
# 6                   Apple iPhone 8 Plus (Gold, 64 GB)     4.6
# 7         Apple iPhone 11 Pro Max (Space Grey, 64 GB)     4.7
# 8                     Apple iPhone XR (White, 128 GB)     4.6
# 9                      Apple iPhone XR (Coral, 64 GB)     4.6
# 10    Apple iPhone 11 Pro Max (Midnight Green, 64 GB)     4.7
# 11            Apple iPhone 11 Pro (Space Grey, 64 GB)     4.7
# 12                Apple iPhone X (Space Gray, 256 GB)     4.6
# 13                 Apple iPhone 7 (Rose Gold, 256 GB)     4.5
# ...

# %%
Product_Details.describe()
# Out:
#                                Product_name Ratings Total_no_of_ratings  \
# count                                   126     126                 126
# unique                                  126       6                  21
# top     Apple iPhone XS Max (Silver, 64 GB)     4.5              24,127
# freq                                      1      44                  13
#
#        Total_reviews      Price                   Status
# count            126        126                      118
# unique            21         63                        2
# top            2,575  Rs 49,900  Temporarily Unavailable
# freq              13          6                       76

# %%
Product_Details.isnull().sum()
# Out:
# Product_name           0
# Ratings                0
# Total_no_of_ratings    0
# Total_reviews          0
# Price                  0
# Status                 8
# dtype: int64

# %%
Product_Details.duplicated().sum()
# Out:
# 0

# %%
Product_Details.to_csv('C:/Users/RIKKI/Desktop/Product_Details.csv',index=False)

# %%
import tkinter as tk
from tkinter import filedialog

# %%
root= tk.Tk()

canvas1 = tk.Canvas(root, width = 300, height = 300, bg = 'lightsteelblue2', relief = 'raised')
canvas1.pack()

# %%
def exportCSV ():
    global df
    
    export_file_path = filedialog.asksaveasfilename(defaultextension='.csv')
    df.to_csv (export_file_path, index = False, header=True)

saveAsButton_CSV = tk.Button(text='Export CSV', command=exportCSV, bg='green', fg='white', font=('helvetica', 12, 'bold'))
canvas1.create_window(150, 150, window=saveAsButton_CSV)

root.mainloop()

# %%
type(np.array(Product_name))
# Out:
# numpy.ndarray

# %%
print(product1.find('_3BTv9X'))
# Out:
# None

# %%
name=product1.img['alt']  #attributes are written in square brakets
name
#product1.find('div',{'class':'_3BTv9X'}).img['alt'
# Out:
# 'Apple iPhone 7 (Black, 32 GB)'

# %%
product1.find('div',{'class':'_3BTv9X'}).img['alt']
# Out:
# 'Apple iPhone 7 (Black, 32 GB)'

# %%
name1=product1.find('img',attrs={'class':'_1Nyybr _30XEf0'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-00cd371a416d> in <module>
#       1 name1=product1.find('img',attrs={'class':'_1Nyybr _30XEf0'})
# ----> 2 name1.img['alt']
#
# TypeError: 'NoneType' object is not subscriptable

# %%
price=product1.find('div',attrs={'class':'_1vC4OE _2rQ-NK'})
price
# Out:
# <div class="_1vC4OE _2rQ-NK">₹29,499</div>

# %%
price=product1.find('div',attrs={'class':'_1vC4OE _2rQ-NK'}).text
price
# Out:
# '₹29,499'

# %%
ratings=product1.find('span',attrs={'class':'_2_KrJI'}).text
ratings
# Out:
# '4.5'

# %%
for a in soup.findAll('a',href=True, attrs={'class':'_31qSD5'}):
    name=a.find('div', attrs={'class':'_3wU53n'}) #Finds all the div tag which have class
    price=a.find('div', attrs={'class':'_1vC4OE _2rQ-NK'})
    rating=a.find('div',attrs={'class':'hGSR34'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-102-342d97ee3c3b> in <module>
# ----> 1 for a in soup.findAll('a',href=True, attrs={'class':'_31qSD5'}):
#       2     name=a.find('div', attrs={'class':'_3wU53n'}) #Finds all the div tag which have class
#       3     price=a.find('div', attrs={'class':'_1vC4OE _2rQ-NK'})
#       4     rating=a.find('div',attrs={'class':'hGSR34'})
#
# NameError: name 'soup' is not defined

# %%
container[0]
# Out:
# <a class="_31qSD5" href="/apple-iphone-7-black-32-gb/p/itmen6daftcqwzeg?pid=MOBEMK62PN2HU7EE&amp;lid=LSTMOBEMK62PN2HU7EEF7TO4A&amp;marketplace=FLIPKART&amp;srno=s_1_1&amp;otracker=search&amp;fm=organic&amp;iid=32016464-3955-4ee2-9fdd-2020c362c899.MOBEMK62PN2HU7EE.SEARCH&amp;ssid=193mvcv1gw0000001586008907217&amp;qH=0b3f45b266a97d70" rel="noopener noreferrer" target="_blank"><div class="_3SQWE6"><div class="_1OCn9C"><div style="-webkit-filter:grayscale(1);-moz-filter:grayscale(1);-o-filter:grayscale(1);-ms-filter:grayscale(1);filter:grayscale(1);opacity:0.6"><div class="_3BTv9X" style="height:200px;width:200px"><img alt="Apple iPhone 7 (Black, 32 GB)" class="_1Nyybr _30XEf0" src="https://rukminim1.flixcart.com/image/312/312/k12go7k0/mobile/7/e/e/apple-iphone-7-mn8x2hn-a-original-imafkqcqhzxuvcpd.jpeg?q=70"/></div></div><div class="_3aV9Tq"><span class="_1GJ2ZM">Not Deliverable</span></div></div><div class="_2lesQu"><div class="_1O_CiZ"><span class="_1iHA1p"><div class="_2kFyHg"><label
# ...
